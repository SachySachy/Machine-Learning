# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


datafile = pd.read_csv('/content/drive/MyDrive/cars.csv')
msrp_feature = np.array(datafile.msrp)
interest_feature = np.array(datafile.interest)

#print(interest_feature)
#print(msrp_feature)

def computation(data, current, matrix1, k_num):
   x,y = np.shape(matrix1)
   matrix1 = np.mat(np.eye((x)))
   for index in range(x):
      sub = current - data[index]
      matrix1[index,index] = np.exp(sub.T/(-2.0*k_num**2))
   return matrix1

def weight(data, current, matrix1, matrix2, k_num):
   weight = computation(data, current, matrix1, k_num)
   return (data.T*(weight*data)).I*(data.T*(weight*matrix2.T))

def LWR(matrix1, matrix2, k_num):
   x,y = np.shape(matrix1)
   #for i in range(m):
     # matrix1[i] = matrix1[i]*weight(matrix1, matrix2[i],matrix1,matrix2,k_num)
   #return matrix1

msrp = msrp_feature.shape[0]
interest = np.mat(interest_feature)
#data = np.hstack((np.ones((m, 1)),
# np.mat(msrp_feature).T))
#y = LWR(data, interest, 0.5)


fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(msrp_feature, interest_feature, color='green')
#ax.plot[x[:,1],y[points], color = 'red', linewidth=4)
plt.xlabel('MSRP for car')
plt.ylabel('value')
plt.show()
